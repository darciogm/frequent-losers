# %%
import pandas as pd

df_won_1 = pd.read_csv('/Users/dvacchini/Library/CloudStorage/Dropbox/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_won_t_minus_1_1_750_market.csv')
df_won_2 = pd.read_csv('/Users/dvacchini/Library/CloudStorage/Dropbox/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_won_t_minus_1500_3500_market.csv')

df_last_1 = pd.read_csv('/Users/dvacchini/Library/CloudStorage/Dropbox/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_last_bid_1_750_market.csv')
df_last_2 = pd.read_csv('/Users/dvacchini/Library/CloudStorage/Dropbox/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_last_bid_1500_3500_market.csv')

df_90won_1 = pd.read_csv('/Users/dvacchini/Library/CloudStorage/Dropbox/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_share_won90_1_750_market.csv')
df_90won_2 = pd.read_csv('/Users/dvacchini/Library/CloudStorage/Dropbox/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_share_won90_1500_3500_market.csv')

df_won = pd.concat([df_won_1, df_won_2], ignore_index=True).drop_duplicates()
df_last = pd.concat([df_last_1, df_last_2], ignore_index=True).drop_duplicates()
df_90won = pd.concat([df_90won_1, df_90won_2], ignore_index=True).drop_duplicates()

df_won = df_won.loc[df_won['Variable'] != '1.flagvencedor#c.MV']
df_last = df_last.loc[df_last['Variable'] != '1.flagvencedor#c.MV']
df_90won = df_90won.loc[df_90won['Variable'] != '1.flagvencedor#c.MV']

# Rename columns if needed to match the example
df_won = df_won.rename(columns={' Market Item': 'market_id', ' Coefficient': 'Incumbency', ' Std. Error': 'std_error', ' Sig_1pct': 'sig_1pct', ' Sig_5pct': 'sig_5pct', ' Sig_10pct': 'sig_10pct'})
df_last = df_last.rename(columns={' Market Item': 'market_id', ' Coefficient': 'Last Bid', ' Std. Error': 'std_error', ' Sig_1pct': 'sig_1pct', ' Sig_5pct': 'sig_5pct', ' Sig_10pct': 'sig_10pct'})
df_90won = df_90won.rename(columns={' Market Item': 'market_id', ' Coefficient': '90-Day Share Won', ' Std. Error': 'std_error', ' Sig_1pct': 'sig_1pct', ' Sig_5pct': 'sig_5pct', ' Sig_10pct': 'sig_10pct'})

df_last = df_last[df_last['market_id'] != 2951]
df_won = df_won[df_won['market_id'] != 2951]
df_90won = df_90won[df_90won['market_id'] != 2951]

df_last = df_last[df_last['market_id'] != 4500]
df_won = df_won[df_won['market_id'] != 4500]
df_90won = df_90won[df_90won['market_id'] != 4500]

df_90won = df_90won[df_90won['market_id'] != 3457]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a binscatter-like plot
sns.regplot(
    x=df_won['Incumbency'],
    y=df_last['Last Bid'],
    ci=None,
    color='dimgrey',                 
    scatter_kws={'s': 20, 'alpha': 0.7},  # Reduce dot size and add transparency
    line_kws={'color': 'black'}, # Optional: set regression line color
)

plt.xlabel('Incumbency')
plt.ylabel('Last Bid')
plt.title('Binscatter: Last Bid vs. Incumbency')
sns.despine()  # Clean up plot borders
plt.tight_layout()

# Save the plot to a file (e.g., PNG)
plt.savefig('/Users/dvacchini/Library/CloudStorage/Dropbox/Projects - Brazilian data/Dario_vacchini/output/graphs/binscatter_incumbency_last_bid_market.pdf', dpi=300, bbox_inches='tight')

# Optional: Show the plot (if you want to display it)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a binscatter-like plot
sns.regplot(
    x=df_won['Incumbency'],
    y=df_90won['90-Day Share Won'],
    ci=None,
    color='dimgrey',                 
    scatter_kws={'s': 20, 'alpha': 0.7},  # Reduce dot size and add transparency
    line_kws={'color': 'black'}, # Optional: set regression line color
)

plt.xlabel('Incumbency')
plt.ylabel('90-Day Share Won')
plt.title('Binscatter: 90-Day Share Won vs. Incumbency')
sns.despine()  # Clean up plot borders
plt.tight_layout()

# Save the plot to a file (e.g., PNG)
plt.savefig('/Users/dvacchini/Library/CloudStorage/Dropbox/Projects - Brazilian data/Dario_vacchini/output/graphs/binscatter_incumbency_backlog_market.pdf', dpi=300, bbox_inches='tight')

# Optional: Show the plot (if you want to display it)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

#create scatterplot with regression line and confidence interval lines
sns.regplot(
    x=df_last['Last Bid'],
    y=df_90won['90-Day Share Won'],
    ci=None,
    color='dimgrey',                 
    scatter_kws={'s': 20, 'alpha': 0.7},  # Reduce dot size and add transparency
    line_kws={'color': 'black'}, # Optional: set regression line color
)

plt.xlabel('Last Bid')
plt.ylabel('90-Day Share Won')
plt.title('Binscatter: 90-Day Share Won vs. Last Bid')
sns.despine()  # Clean up plot borders
plt.tight_layout()

# Save the plot to a file (e.g., PNG)
plt.savefig('/Users/dvacchini/Library/CloudStorage/Dropbox/Projects - Brazilian data/Dario_vacchini/output/graphs/binscatter_last_bid_backlog_market.pdf', dpi=300, bbox_inches='tight')

# Optional: Show the plot (if you want to display it)
plt.show()

# %%
import pandas as pd

df_won_1 = pd.read_csv('C:/Users/sergioga/Sergio DB Dropbox/Sergio Galletta/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_won_t_minus_1_1_750_market.csv')
df_won_2 = pd.read_csv('C:/Users/sergioga/Sergio DB Dropbox/Sergio Galletta/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_won_t_minus_1500_3500_market.csv')

df_last_1 = pd.read_csv('C:/Users/sergioga/Sergio DB Dropbox/Sergio Galletta/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_last_bid_1_750_market.csv') 
df_last_2 = pd.read_csv('C:/Users/sergioga/Sergio DB Dropbox/Sergio Galletta/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_last_bid_1500_3500_market.csv')

df_90won_1 = pd.read_csv('C:/Users/sergioga/Sergio DB Dropbox/Sergio Galletta/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_share_won90_1_750_market.csv') 
df_90won_2 = pd.read_csv('C:/Users/sergioga/Sergio DB Dropbox/Sergio Galletta/Projects - Brazilian data/Dario_vacchini/data/raw/market/reg_share_won90_1500_3500_market.csv')

df_won = pd.concat([df_won_1, df_won_2], ignore_index=True).drop_duplicates()
df_last = pd.concat([df_last_1, df_last_2], ignore_index=True).drop_duplicates()
df_90won = pd.concat([df_90won_1, df_90won_2], ignore_index=True).drop_duplicates()

df_won = df_won.loc[df_won['Variable'] != '1.flagvencedor#c.MV']
df_last = df_last.loc[df_last['Variable'] != '1.flagvencedor#c.MV']
df_90won = df_90won.loc[df_90won['Variable'] != '1.flagvencedor#c.MV']

# Rename columns if needed to match the example
df_won = df_won.rename(columns={' Market Item': 'market_id', ' Coefficient': 'Incumbency', ' Std. Error': 'std_error', ' Sig_1pct': 'sig_1pct', ' Sig_5pct': 'sig_5pct', ' Sig_10pct': 'sig_10pct'})
df_last = df_last.rename(columns={' Market Item': 'market_id', ' Coefficient': 'Last Bid', ' Std. Error': 'std_error', ' Sig_1pct': 'sig_1pct', ' Sig_5pct': 'sig_5pct', ' Sig_10pct': 'sig_10pct'})
df_90won = df_90won.rename(columns={' Market Item': 'market_id', ' Coefficient': '90-Day Share Won', ' Std. Error': 'std_error', ' Sig_1pct': 'sig_1pct', ' Sig_5pct': 'sig_5pct', ' Sig_10pct': 'sig_10pct'})

df_last = df_last[df_last['market_id'] != 2951]
df_won = df_won[df_won['market_id'] != 2951]
df_90won = df_90won[df_90won['market_id'] != 2951]

df_last = df_last[df_last['market_id'] != 4500]
df_won = df_won[df_won['market_id'] != 4500]
df_90won = df_90won[df_90won['market_id'] != 4500]

df_90won = df_90won[df_90won['market_id'] != 3457]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Calculate the regression coefficient and standard error
x = df_won_significant['Incumbency (Standardized)']
y = df_last_significant['Last Bid (Standardized)']
regression = np.polyfit(x, y, 1)
coefficient = regression[0]
intercept = regression[1]

# Calculate standard error of the coefficient
y_pred = np.polyval(regression, x)
residuals = y - y_pred
sw = np.sqrt(np.sum(residuals**2) / (len(y) - 2)) / np.sqrt(np.sum((x - np.mean(x))**2))

# Create a binscatter-like plot for standardized variables
sns.regplot(
    x=x,
    y=y,
    ci=None,
    color='dimgrey',
    scatter_kws={'s': 20, 'alpha': 0.7},  # Reduce dot size and add transparency
    line_kws={'color': 'black'},  # Optional: set regression line color
)

plt.xlabel('Incumbency (Standardized)')
plt.ylabel('Last Bid (Standardized)')

# Add coefficient and standard error as text on the plot
plt.text(
    0.05, 0.95, f'Coef: {coefficient:.3f}, SE: {sw:.3f}',
    transform=plt.gca().transAxes,
    fontsize=10,
    verticalalignment='top'
)

sns.despine()  # Clean up plot borders
plt.tight_layout()

# Save the plot to a file (e.g., PNG)
plt.savefig('C:/Users/sergioga/Sergio DB Dropbox/Sergio Galletta/Projects - Brazilian data/Dario_vacchini/output/graphs/binscatter_standardized_incumbency_last_bid_market_significant.pdf', dpi=300, bbox_inches='tight')

# Optional: Show the plot (if you want to display it)
plt.show()
